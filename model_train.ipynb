# %%
from train import train_model
from config import get_config

# %%
cfg = get_config()
train_model(cfg)
# Out:
# Using device: cuda
# NOTE: If you have a GPU, consider using it for training.
#       On a Windows machine with NVidia GPU, check this video: https://www.youtube.com/watch?v=GMSjDTU8Zlc
#       On a Mac machine, run: pip3 install --pre torch torchvision torchaudio torchtext --index-url https://download.pytorch.org/whl/nightly/cpu
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Max length of source sentense: 106
# Max length of target sentense: 91
# Preloading model weights/tmodel_19.pt
# Processing Epoch 20: 100%|██████████| 450/450 [02:43<00:00,  2.75it/s, loss=2.352]
# --------------------------------------------------------------------------------
# SOURCE: - George?
# TARGET: - ජෝර්ජ්?
# PREDICTED: - පිරිමි ?
# --------------------------------------------------------------------------------
# SOURCE: So you can the people caught hold on SkyArk.
# ...
