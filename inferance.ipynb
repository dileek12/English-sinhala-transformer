# %%
from pathlib import Path
import torch
import torch.nn as nn
from config import get_config, latest_weights_file_path
from train import get_model, get_ds, run_validation

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
config = get_config()
train_dataloader, val_dataloader, tokenizer_src, tokenizer_tgt = get_ds(config)
model = get_model(config, tokenizer_src.get_vocab_size(), tokenizer_tgt.get_vocab_size()).to(device)

# Load the pretrained weights
model_filename = latest_weights_file_path(config)
if model_filename is None:
    print(f"No trained model weights found!")
else:
    print(f"Loading model: {model_filename}")
    state = torch.load(model_filename, map_location=device)
    model.load_state_dict(state['model_state_dict'])
# Out:
# Using device: cpu
# Max length of source sentense: 46
# Max length of target sentense: 43
# Loading model: weights\tmodel_48.pt

# %%
run_validation(model, val_dataloader, tokenizer_src, tokenizer_tgt, config['seq_len'], device, lambda msg: print(msg), 0, None, num_examples=10)
# Out:
# --------------------------------------------------------------------------------
# SOURCE: - I would like to go to Mars.
# TARGET: - මමත් කැමතියි අඟහරු වලට යන්න.
# PREDICTED: - මං කැමති වෙනවා .
# --------------------------------------------------------------------------------
# SOURCE: Yes, we look similar.
# TARGET: ඔව්, අපි එක වගේ.
# PREDICTED: ඔව් , අපි එක වගේ .
# --------------------------------------------------------------------------------
# SOURCE: There was a girl.
# TARGET: එතන කෙල්ලෙක් හිටියා.
# PREDICTED: එතන කෙල්ලෙක් හිටියා .
# --------------------------------------------------------------------------------
# SOURCE: What did he say?
# TARGET: මොකද උණේ අයියේ?
# PREDICTED: මොකද අයියේ ?
# --------------------------------------------------------------------------------
# SOURCE: All right, OK, OK.
# TARGET: හරි, හරි, හරි.
# PREDICTED: හරි , හරි , හරි .
# --------------------------------------------------------------------------------
# SOURCE: Park the car this side.
# TARGET: වාහනේ පැත්තකට ගන්නවා.
# PREDICTED: වාහනේ පැත්තකට ගන්නවා .
# --------------------------------------------------------------------------------
# SOURCE: - Wren, they got nothing to do with this.
# TARGET: ඔවුන් මේකට සම්බන්ධ නෑ..
# PREDICTED: ඔවුන් මේකට සම්බන්ධ නෑ ..
# --------------------------------------------------------------------------------
# SOURCE: - Seems good to me.
# TARGET: මට නම් අවුලක් නෑ.
# PREDICTED: මට නම් අවුලක් නෑ .
# --------------------------------------------------------------------------------
# SOURCE: Go!
# TARGET: යන්න!
# PREDICTED: යන්න !
# --------------------------------------------------------------------------------
# SOURCE: AltGraph
# TARGET: AltGraph
# PREDICTED:
# --------------------------------------------------------------------------------

# %%
from translate import translate

# %%
t = translate("Why do I need to translate this?")
t = translate(34)
# Out:
# Using device: cpu
#     SOURCE: Why do I need to translate this?
#  PREDICTED: ඇයි මට මේ මට   ?  Using device: cpu
#         ID: 34
#     SOURCE: -Sir, Parithi..
#     TARGET: -මහත්තයා අපි... පරිති..
#  PREDICTED: - මහත්තයා මහත්තයා අපි ...
